38807.jpg","184x184":"https://res.cloudinary.com/tf-lab/image/upload/f_auto,q_auto,w_184,h_184/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg"},"mainPhotoSrc":"https://res.cloudinary.com/tf-lab/image/upload/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg","hasLoyaltyProgram":true,"isBookable":true,"isInsider":false,"uuid":"bc1f87d6-94c4-419e-a0d3-e56e9cd132c2","marketingOffer":null,"bestOffer":{"tagsIds":[],"id":"2c9e670f-f7dc-4d4d-ba92-82207f5d65d7","name":"30% off food","label":"-30%"},"canBurnYums":true,"yumsDetail":{"isSuperYums":true,"description":"YUMS x2"},"highlightedTag":[{"id":"4339","slug":"yums-x2","indexable":false,"text":"YUMS x2","type":"SUPER_YUMS"},{"id":"4367","slug":"thefork-pay","indexable":false,"text":"PAY","type":"TF_PAY"},{"id":"5779","slug":"gift-cards","indexable":false,"text":"Gift cards","type":"GIFT_CARD"},{"id":"436","slug":"italian","indexable":true,"text":"Italian","type":"DEFAULT"},{"id":"831","slug":"loyalty-program","indexable":true,"text":"Accepting my yums","type":"YUMS_ACCEPTED"}],"photosCarousel":[{"source":"https://res.cloudinary.com/tf-lab/image/upload/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg","612x344":"https://res.cloudinary.com/tf-lab/image/upload/f_auto,q_auto,w_612,h_344/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg","480x270":"https://res.cloudinary.com/tf-lab/image/upload/f_auto,q_auto,w_480,h_270/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg","240x135":"https://res.cloudinary.com/tf-lab/image/upload/f_auto,q_auto,w_240,h_135/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg","664x374":"https://res.cloudinary.com/tf-lab/image/upload/f_auto,q_auto,w_664,h_374/restaurant/bc1f87d6-94c4-419e-a0d3-e56e9cd132c2/3ace0121-6569-4473-8c71-1f29aff38807.jpg","1350x759":"https://res.cloudinary.com/tf-lab/image/upload/ ...

# %%
doc = response.json()

# %%
doc.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
doc['meta'].keys()
# Out:
# dict_keys(['city', 'filters', 'location', 'sort', 'theForkAdvantages', 'tagCategories', 'price', 'broadGeo', 'page', 'cityId', 'countryId'])

# %%
doc['meta']['city']
# Out:
# {'slugsByLocale': {'it-IT': 'milano',
#   'fr-FR': 'milan',
#   'es-ES': 'milan',
#   'ca-ES': 'mila',
#   'fr-CH': 'milan',
#   'de-CH': 'mailand',
#   'en-US': 'milan',
#   'nl-BE': 'milaan',
#   'fr-BE': 'milan',
#   'sv-SE': 'milano',
#   'nl-NL': 'milaan',
#   'pt-PT': 'milan',
#   'en-AU': 'milan',
#   'de-DE': 'mailand',
#   'de-AT': 'mailand',
#   'en-GB': 'milan'},
#  'id': 348156,
#  'name': 'Milan',
#  'countryId': 111,
#  'slug': 'milan',
#  'hasHomepage': True,
#  'latitude': 45.4642035,
#  'longitude': 9.189981999999986,
#  'isSeoIndexed': True,
#  'photo': 'https://c.tfstatic.com/homepage_city/348156.jpg'}

# %%
doc['meta']['location']
# Out:
# {'city': {'slugsByLocale': {'it-IT': 'milano',
#    'fr-FR': 'milan',
#    'es-ES': 'milan',
#    'ca-ES': 'mila',
#    'fr-CH': 'milan',
#    'de-CH': 'mailand',
#    'en-US': 'milan',
#    'nl-BE': 'milaan',
#    'fr-BE': 'milan',
#    'sv-SE': 'milano',
#    'nl-NL': 'milaan',
#    'pt-PT': 'milan',
#    'en-AU': 'milan',
#    'de-DE': 'mailand',
#    'de-AT': 'mailand',
#    'en-GB': 'milan'},
#   'id': 348156,
#   'name': 'Milan',
#   'countryId': 111,
#   'slug': 'milan',
#   'hasHomepage': True,
#   'latitude': 45.4642035,
#   'longitude': 9.189981999999986,
#   'isSeoIndexed': True,
#   'photo': 'https://c.tfstatic.com/homepage_city/348156.jpg'},
#  'type': 'city',
#  'radius': None}

# %%
doc['meta']['price']
# Out:
# {'values': [0, 50, 100, 150], 'currencies': 'EUR'}

# %%
doc['data'][0].keys()
# Out:
# dict_keys(['name', 'slug', 'geo', 'servesCuisine', 'containedInPlace', 'priceRange', 'currenciesAccepted', 'address', 'aggregateRatings', 'mainPhoto', 'mainPhotoSrc', 'hasLoyaltyProgram', 'isBookable', 'isInsider', 'uuid', 'marketingOffer', 'bestOffer', 'canBurnYums', 'yumsDetail', 'highlightedTag', 'photosCarousel', 'isBookmarked', 'id'])

# %%
doc['data'][0]['address']
# Out:
# {'street': 'Via Nino Bonnet, 11',
#  'postalCode': '20154',
#  'locality': 'Milano',
#  'country': 'Italy'}

# %%
doc['data'][0]['servesCuisine']
# Out:
# 'Italian'

# %%
doc['data'][2]['containedInPlace']
# Out:
# {}

# %%
doc['data'][2]['priceRange']
# Out:
# 25

# %%
len(doc['data'])
# Out:
# 10

# %%
url = "https://the-fork-the-spoon.p.rapidapi.com/locations/v2/auto-complete"

querystring = {"text":"new york"}

headers = {
	"X-RapidAPI-Key": "e4a1f0be3cmshe96ad71b187ed76p1822d0jsn963e6526e22a",
	"X-RapidAPI-Host": "the-fork-the-spoon.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":{"geolocation":[{"__typename":"GeoLocationList","type":"google","id":{"__typename":"SearchGeolocationID","id":"ChIJOwg_06VPwokRYv534QaPC8g","type":"locality"},"name":{"__typename":"AutocompleteName","text":"New York, NY, USA","highlight":[{"__typename":"AutocompleteHighlight","offset":0,"length":8}]}},{"__typename":"GeoLocationList","type":"google","id":{"__typename":"SearchGeolocationID","id":"ChIJqaUj8fBLzEwRZ5UY3sHGz90","type":"administrative_area_level_1"},"name":{"__typename":"AutocompleteName","text":"New York State, USA","highlight":[{"__typename":"AutocompleteHighlight","offset":0,"length":8}]}}]}}

# %%
m = response.json()

# %%
m
# Out:
# {'data': {'geolocation': [{'__typename': 'GeoLocationList',
#     'type': 'google',
#     'id': {'__typename': 'SearchGeolocationID',
#      'id': 'ChIJOwg_06VPwokRYv534QaPC8g',
#      'type': 'locality'},
#     'name': {'__typename': 'AutocompleteName',
#      'text': 'New York, NY, USA',
#      'highlight': [{'__typename': 'AutocompleteHighlight',
#        'offset': 0,
#        'length': 8}]}},
#    {'__typename': 'GeoLocationList',
#     'type': 'google',
#     'id': {'__typename': 'SearchGeolocationID',
#      'id': 'ChIJqaUj8fBLzEwRZ5UY3sHGz90',
#      'type': 'administrative_area_level_1'},
#     'name': {'__typename': 'AutocompleteName',
#      'text': 'New York State, USA',
#      'highlight': [{'__typename': 'AutocompleteHighlight',
#        'offset': 0,
#        'length': 8}]}}]}}

# %%
url = "https://the-fork-the-spoon.p.rapidapi.com/locations/v2/list"

querystring = {"google_place_id":"ChIJOwg_06VPwokRYv534QaPC8g","geo_ref":"false","geo_text":"Roma, Metropolitan City of Rome, Italy","geo_type":"locality"}

headers = {
	"X-RapidAPI-Key": "e4a1f0be3cmshe96ad71b187ed76p1822d0jsn963e6526e22a",
	"X-RapidAPI-Host": "the-fork-the-spoon.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

m = response.json()

# %%
m
# Out:
# {'coordinates': {'latitude': 40.7127753, 'longitude': -74.0059728},
#  'prediction': {'address_components': [{'long_name': 'New York',
#     'short_name': 'New York',
#     'types': ['locality', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'New York, NY, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 40.9175771, 'lng': -73.7002721},
#     'southwest': {'lat': 40.4773991, 'lng': -74.2590899}},
#    'location': {'lat': 40.7127753, 'lng': -74.0059728},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 40.9175771, 'lng': -73.7002721},
#     'southwest': {'lat': 40.4773991, 'lng': -74.2590899}}},
#   'place_id': 'ChIJOwg_06VPwokRYv534QaPC8g',
#   'types': ['locality', 'political']}}
